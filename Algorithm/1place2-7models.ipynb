# %%
#!/usr/bin/python3.7

# %%
import time
import sklearn
import numpy as np
import pandas as pd

import sys
sys.path.append("..")
from baggingPU import BaggingClassifierPU

from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import random

# %%
def print_cm(cm, labels, hide_zeroes=False, hide_diagonal=False, hide_threshold=None):
    columnwidth = max([len(x) for x in labels]) + 4
    empty_cell = " " * columnwidth
    print("    " + empty_cell, end=' ')
    for label in labels:
        print("%{0}s".format(columnwidth) % 'pred_' + label, end=" ")
    print()

    for i, label1 in enumerate(labels):
        print("    %{0}s".format(columnwidth) % 'true_' + label1, end=" ")
        for j in range(len(labels)):
            cell = "%{0}.1f".format(columnwidth) % cm[i, j]
            if hide_zeroes:
                cell = cell if float(cm[i, j]) != 0 else empty_cell
            if hide_diagonal:
                cell = cell if i != j else empty_cell
            if hide_threshold:
                cell = cell if cm[i, j] > hide_threshold else empty_cell
            if cell:
                print(cell, end=" ")
        print()

# %% [markdown]
# # import data

# %%
#df_raw = pd.read_csv('../data/w-dependence.csv')

df_raw = pd.read_csv('../data/1-place2.csv')

#df_raw = pd.read_csv('../data/w-related.csv')

df_raw['label'] = df_raw['label'].astype("int")
print(df_raw.label.value_counts())
print('Has null values', df_raw.isnull().values.any())
# Out:
# 0    10000
# 1    10000
# Name: label, dtype: int64
# Has null values False

# %%
df_raw.head(10)
# Out:
#    p1  p2  label
# 0   1   0      1
# 1   1   2      1
# 2   1   4      1
# 3   1   6      1
# 4   1   8      1
# 5   1  10      1
# 6   1  12      1
# 7   1  14      1
# 8   1  16      1
# 9   1  18      1

# %%
print(df_raw.iloc[:10000,:])
df_max = np.amax(df_raw.iloc[:10000,:])
print(df_max)
# Out:
#       p1     p2  label
# 0      1      0      1
# 1      1      2      1
# 2      1      4      1
# 3      1      6      1
# 4      1      8      1
# ...   ..    ...    ...
# 9995   1  19990      1
# 9996   1  19992      1
# 9997   1  19994      1
# 9998   1  19996      1
# 9999   1  19998      1
#
# [10000 rows x 3 columns]
# p1           1
# p2       19998
# label        1
# dtype: int64

# %%
print(df_raw.iloc[10000:,:])
print(np.amax(df_raw.iloc[10000:,[1]]))
# Out:
#        p1     p2  label
# 10000   1      1      0
# 10001   1      3      0
# 10002   1      5      0
# 10003   1      7      0
# 10004   1      9      0
# ...    ..    ...    ...
# 19995   1  19991      0
# 19996   1  19993      0
# 19997   1  19995      0
# 19998   1  19997      0
# 19999   1  19999      0
#
# [10000 rows x 3 columns]
# p2    19999
# dtype: int64

# %%
neg_process = df_raw.iloc[10000:,:].copy()
print(neg_process)

for i in range(10000):
    if neg_process.iloc[i,1] > df_max[0]:
        neg_process.iloc[i,1]  = int(neg_process.iloc[i,1] / df_max[0])
# Out:
#        p1     p2  label
# 10000   1      1      0
# 10001   1      3      0
# 10002   1      5      0
# 10003   1      7      0
# 10004   1      9      0
# ...    ..    ...    ...
# 19995   1  19991      0
# 19996   1  19993      0
# 19997   1  19995      0
# 19998   1  19997      0
# 19999   1  19999      0
#
# [10000 rows x 3 columns]

# %%
neg_process.drop_duplicates(inplace=True)
print(neg_process)
print(len(neg_process))
print(np.amax(neg_process))
# Out:
#        p1     p2  label
# 10000   1      1      0
# 10001   1      3      0
# 10002   1      5      0
# 10003   1      7      0
# 10004   1      9      0
# ...    ..    ...    ...
# 19995   1  19991      0
# 19996   1  19993      0
# 19997   1  19995      0
# 19998   1  19997      0
# 19999   1  19999      0
#
# [10000 rows x 3 columns]
# 10000
# p1           1
# p2       19999
# label        0
# dtype: int64

# %%
df_process = pd.concat([df_raw.iloc[:10000,:], neg_process])
print(df_process)
# Out:
#        p1     p2  label
# 0       1      0      1
# 1       1      2      1
# 2       1      4      1
# 3       1      6      1
# 4       1      8      1
# ...    ..    ...    ...
# 19995   1  19991      0
# 19996   1  19993      0
# 19997   1  19995      0
# 19998   1  19997      0
# 19999   1  19999      0
#
# [20000 rows x 3 columns]

# %%
x_data = df_process.iloc[:,:-1]
y_data = df_process.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=7)

# %%
x_train_input = pd.concat([x_train.iloc[:,:], y_train],axis=1)
x_test_input = pd.concat([x_test.iloc[:,:],y_test],axis=1)

print(len(x_train_input))
print(len(x_test_input))

print(x_train_input.label.value_counts())
print('Has null values', x_train_input.isnull().values.any())

print(x_test_input.label.value_counts())
print('Has null values', x_test_input.isnull().values.any())
# Out:
# 16000
# 4000
# 1    8077
# 0    7923
# Name: label, dtype: int64
# Has null values False
# 0    2077
# 1    1923
# Name: label, dtype: int64
# Has null values False

# %%
x_train_input.head(10)
# Out:
#        p1     p2  label
# 8118    1  16236      1
# 10171   1    343      0
# 9399    1  18798      1
# 12669   1   5339      0
# 18809   1  17619      0
# 13869   1   7739      0
# 3320    1   6640      1
# 14689   1   9379      0
# 13087   1   6175      0
# 15992   1  11985      0

# %%
x_test_input.head(10)
# Out:
#        p1     p2  label
# 14356   1   8713      0
# 3439    1   6878      1
# 12153   1   4307      0
# 15029   1  10059      0
# 18549   1  17099      0
# 15762   1  11525      0
# 12313   1   4627      0
# 16034   1  12069      0
# 11496   1   2993      0
# 5653    1  11306      1

# %%
df = x_train_input.copy()

NON_LBL = [c for c in df.columns if c != 'label']
X = df[NON_LBL]
y = df['label']

y_orig = y.copy()

hidden_size = 5000
y.loc[
    np.random.choice(
        y[y == 1].index, 
        replace = False, 
        size = hidden_size
    )
] = 0

print(X)
print(y)
# Out:
#        p1     p2
# 8118    1  16236
# 10171   1    343
# 9399    1  18798
# 12669   1   5339
# 18809   1  17619
# ...    ..    ...
# 13927   1   7855
# 919     1   1838
# 5699    1  11398
# 10742   1   1485
# 16921   1  13843
#
# [16000 rows x 2 columns]
# 8118     1
# 10171    0
# 9399     1
# 12669    0
# 18809    0
#         ..
# 13927    0
# 919      1
# 5699     0
# 10742    0
# 16921    0
# Name: label, Length: 16000, dtype: int64

# %%
pd.Series(y).value_counts()
# Out:
# 0    12923
# 1     3077
# Name: label, dtype: int64

# %%
print('- %d samples and %d features' % (X.shape))
print('- %d positive out of %d total before hiding labels' % (sum(df_process.label), len(df_process.label)))
print('- %d positive out of %d total after hiding labels' % (sum(y), len(y)))
# Out:
# - 16000 samples and 2 features
# - 10000 positive out of 20000 total before hiding labels
# - 3077 positive out of 16000 total after hiding labels

# %% [markdown]
# # Trainning directly

# %%
print('Training XGboost model ...')

import xgboost as xgb

model = xgb.XGBClassifier()
model.fit(X, y)

print('Done')
# Out:
# Training XGboost model ...
# Done

# %%
print('---- {} ----'.format('XGboost model'))
print(print_cm(sklearn.metrics.confusion_matrix(y_orig, model.predict(X)), labels=['negative', 'positive']))
print('')
print('Precision: ', precision_score(y_orig, model.predict(X)))
print('Recall: ', recall_score(y_orig, model.predict(X)))
print('Accuracy: ', accuracy_score(y_orig, model.predict(X)))
print('f1_score: ', f1_score(y_orig, model.predict(X)))
# Out:
# ---- XGboost model ----
#                         pred_negative        pred_positive
#            true_negative       7922.0          1.0
#            true_positive       8065.0         12.0
# None
#
# Precision:  0.9230769230769231
# Recall:  0.0014857001361891792
# Accuracy:  0.495875
# f1_score:  0.002966625463535229

# %% [markdown]
# # Training by bagging

# %%
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression()

from sklearn.tree import DecisionTreeClassifier
model2 = DecisionTreeClassifier()

from sklearn.neural_network import MLPClassifier
model3 = MLPClassifier(solver='adam', alpha=1e-5,hidden_layer_sizes=(1), random_state=1,max_iter=100000)

from sklearn import svm
model4 = svm.LinearSVC()

from sklearn.naive_bayes import MultinomialNB
model5 = MultinomialNB()

from sklearn.ensemble import RandomForestClassifier
model6 = RandomForestClassifier(n_estimators = 50,n_jobs = -1)

import xgboost as xgb
model7 = xgb.XGBClassifier()

# %%
model_list = [model1, model2, model3, model4, model5, model6, model7]

# %%
print('Training Logistics Regression model...')
Time = 0.0
precision_train = 0.0
recall_train = 0.0
accuracy_train = 0.0
f1_train = 0.0

precision_test = 0.0
recall_test = 0.0
accuracy_test = 0.0
f1_test = 0.0

for i in range(10):

    print('Training bagging classifier...')
    pu_start = time.perf_counter()
    model = BaggingClassifierPU(model1,
                             n_estimators = 50, 
                             n_jobs = -1, 
                             max_samples = sum(y) 
                        )
    model.fit(X, y)

    pre = model.predict(X)
    pu_end = time.perf_counter()
    print('Done!')
    print('Time:', pu_end - pu_start)
    Time += (pu_end - pu_start)
    
    #train data
    print('---- {} ----'.format('PU Bagging Train data'))
    print(print_cm(sklearn.metrics.confusion_matrix(y_orig, pre), labels=['negative', 'positive']))
    print('')
    print('Precision: ', precision_score(y_orig, pre))
    print('Recall: ', recall_score(y_orig, pre))
    print('Accuracy: ', accuracy_score(y_orig, pre))
    print('f1_score: ', f1_score(y_orig, pre))
   
    #test data
    pre_test = model.predict(x_test)
    print('---- {} ----'.format('PU Bagging Test data'))
    print(print_cm(sklearn.metrics.confusion_matrix(y_test,pre_test ), labels=['negative', 'positive']))
    print('')
    print('Precision: ', precision_score(y_test, pre_test))
    print('Recall: ', recall_score(y_test, pre_test))
    print('Accuracy: ', accuracy_score(y_test, pre_test))
    print('f1_score: ', f1_score(y_test, pre_test))
    
    
    precision_train += precision_score(y_orig, pre)
    recall_train += recall_score(y_orig, pre)
    accuracy_train += accuracy_score(y_orig, pre)
    f1_train += f1_score(y_orig, pre)
    
    precision_test += precision_score(y_test,pre_test)
    recall_test += recall_score(y_test, pre_test)
    accuracy_test += accuracy_score(y_test, pre_test)
    f1_test += f1_score(y_test, pre_test)
    
print("===========================")
print("The final results:")
print("Time:" , Time / 10)
print("precision_train:" , precision_train / 10)
print("recall_train:" , recall_train / 10)
print("accuracy_train:" , accuracy_train / 10)
print("f1_train:" , f1_train / 10)
print("precision_test:" , precision_test / 10)
print("recall_test:" , recall_test / 10)
print("accuracy_test:" , accuracy_test / 10)
print("f1_test:" , f1_test / 10)
# Out:
# Training Logistics Regression model...
# Training bagging classifier...
# Done!
# Time: 8.886250629999267
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative         27.0       7896.0
#            true_positive         27.0       8050.0
# None
#
# Precision:  0.504828797190518
# Recall:  0.9966571746935744
# Accuracy:  0.5048125
# f1_score:  0.6701910668942264
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative          5.0       2072.0
#            true_positive          5.0       1918.0
# None
#
# Precision:  0.4807017543859649
# Recall:  0.9973998959958398
# Accuracy:  0.48075
# f1_score:  0.6487400642651784
# Training bagging classifier...
# Done!
# Time: 4.127701403995161
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative          0.0       7923.0
#            true_positive          0.0       8077.0
# None
#
# Precision:  0.5048125
# Recall:  1.0
# Accuracy:  0.5048125
# f1_score:  0.6709307637994767
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative          0.0       2077.0
#            true_positive          0.0       1923.0
# None
#
# Precision:  0.48075
# Recall:  1.0
# Accuracy:  0.48075
# f1_score:  0.6493331082221847
# Training bagging classifier...
# Done!
# Time: 3.102969318999385
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       7923.0          0.0
#            true_positive       8077.0          0.0
# None
#
# Precision:  0.0
# Recall:  0.0
# Accuracy:  0.4951875
# f1_score:  0.0
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       2077.0          0.0
#            true_positive       1923.0          0.0
# None
#
# Precision:  0.0
# Recall:  0.0
# Accuracy:  0.51925
# f1_score:  0.0
# Training bagging classifier...
# Done!
# Time: 3.4031894540021312
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative        997.0       6926.0
#            true_positive       1040.0       7037.0
# None
#
# Precision:  0.503974790517797
# Recall:  0.8712393215302712
# Accuracy:  0.502125
# f1_score:  0.6385662431941923
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        283.0       1794.0
#            true_positive        241.0       1682.0
# None
#
# Precision:  0.48388952819332565
# Recall:  0.87467498699948
# Accuracy:  0.49125
# f1_score:  0.6230783478421931
# Training bagging classifier...
# Done!
# Time: 0.8554968690004898
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative        956.0       6967.0
#            true_positive        993.0       7084.0
# None
#
# Precision:  0.5041634047398762
# Recall:  0.8770583137303454
# Accuracy:  0.5025
# f1_score:  0.6402747650036154
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        268.0       1809.0
#            true_positive        231.0       1692.0
# None
#
# Precision:  0.4832904884318766
# Recall:  0.8798751950078003
# Accuracy:  0.49
# f1_score:  0.6238938053097346
# Training bagging classifier...
# Done!
# Time: 3.541143902002659
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       4793.0       3130.0
#            true_positive       4946.0       3131.0
# None
#
# Precision:  0.5000798594473727
# Recall:  0.38764392720069335
# Accuracy:  0.49525
# f1_score:  0.4367415260147859
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1298.0        779.0
#            true_positive       1145.0        778.0
# None
#
# Precision:  0.49967886962106617
# Recall:  0.4045761830473219
# Accuracy:  0.519
# f1_score:  0.4471264367816092
# Training bagging classifier...
# Done!
# Time: 3.4990517309997813
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative          0.0       7923.0
#            true_positive          0.0       8077.0
# None
#
# Precision:  0.5048125
# Recall:  1.0
# Accuracy:  0.5048125
# f1_score:  0.6709307637994767
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative          0.0       2077.0
#            true_positive          0.0       1923.0
# None
#
# Precision:  0.48075
# Recall:  1.0
# Accuracy:  0.48075
# f1_score:  0.6493331082221847
# Training bagging classifier...
# Done!
# Time: 3.7699713060064823
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative          0.0       7923.0
#            true_positive          0.0       8077.0
# None
#
# Precision:  0.5048125
# Recall:  1.0
# Accuracy:  0.5048125
# f1_score:  0.6709307637994767
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative          0.0       2077.0
#            true_positive          0.0       1923.0
# None
#
# Precision:  0.48075
# Recall:  1.0
# Accuracy:  0.48075
# f1_score:  0.6493331082221847
# Training bagging classifier...
# Done!
# Time: 3.148929101000249
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       1281.0       6642.0
#            true_positive       1330.0       6747.0
# None
#
# Precision:  0.5039211292852341
# Recall:  0.835334901572366
# Accuracy:  0.50175
# f1_score:  0.628622006894624
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        368.0       1709.0
#            true_positive        320.0       1603.0
# None
#
# Precision:  0.4839975845410628
# Recall:  0.8335933437337494
# Accuracy:  0.49275
# f1_score:  0.6124164278892072
# Training bagging classifier...
# Done!
# Time: 2.562233037002443
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative          0.0       7923.0
#            true_positive          0.0       8077.0
# None
#
# Precision:  0.5048125
# Recall:  1.0
# Accuracy:  0.5048125
# f1_score:  0.6709307637994767
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative          0.0       2077.0
#            true_positive          0.0       1923.0
# None
#
# Precision:  0.48075
# Recall:  1.0
# Accuracy:  0.48075
# f1_score:  0.6493331082221847
# ===========================
# The final results:
# Time: 3.6896936753008047
# precision_train: 0.4536217981180798
# recall_train: 0.796793363872725
# accuracy_train: 0.5020875
# f1_train: 0.569811866319935
# precision_test: 0.4354558225173296
# recall_test: 0.7990119604784192
# accuracy_test: 0.49160000000000004
# f1_test: 0.555258751497666

# %%
print('Training Decision Tree model...')
Time = 0.0
precision_train = 0.0
recall_train = 0.0
accuracy_train = 0.0
f1_train = 0.0

precision_test = 0.0
recall_test = 0.0
accuracy_test = 0.0
f1_test = 0.0

for i in range(10):

    print('Training bagging classifier...')
    pu_start = time.perf_counter()
    model = BaggingClassifierPU(model2,
                             n_estimators = 50, 
                             n_jobs = -1, 
                             max_samples = sum(y) 
                        )
    model.fit(X, y)
    pre = model.predict(X)
    pu_end = time.perf_counter()
    print('Done!')
    print('Time:', pu_end - pu_start)
    Time += (pu_end - pu_start)
    
    #train data
    print('---- {} ----'.format('PU Bagging Train data'))
    print(print_cm(sklearn.metrics.confusion_matrix(y_orig, pre), labels=['negative', 'positive']))
    print('')
    print('Precision: ', precision_score(y_orig, pre))
    print('Recall: ', recall_score(y_orig, pre))
    print('Accuracy: ', accuracy_score(y_orig, pre))
    print('f1_score: ', f1_score(y_orig, pre))
   
    #test data
    pre_test = model.predict(x_test)
    print('---- {} ----'.format('PU Bagging Test data'))
    print(print_cm(sklearn.metrics.confusion_matrix(y_test,pre_test ), labels=['negative', 'positive']))
    print('')
    print('Precision: ', precision_score(y_test, pre_test))
    print('Recall: ', recall_score(y_test, pre_test))
    print('Accuracy: ', accuracy_score(y_test, pre_test))
    print('f1_score: ', f1_score(y_test, pre_test))
    
    
    precision_train += precision_score(y_orig, pre)
    recall_train += recall_score(y_orig, pre)
    accuracy_train += accuracy_score(y_orig, pre)
    f1_train += f1_score(y_orig, pre)
    
    precision_test += precision_score(y_test,pre_test)
    recall_test += recall_score(y_test, pre_test)
    accuracy_test += accuracy_score(y_test, pre_test)
    f1_test += f1_score(y_test, pre_test)
    

print("The final results:")
print("Time:" , Time / 10)
print("precision_train:" , precision_train / 10)
print("recall_train:" , recall_train / 10)
print("accuracy_train:" , accuracy_train / 10)
print("f1_train:" , f1_train / 10)
print("precision_test:" , precision_test / 10)
print("recall_test:" , recall_test / 10)
print("accuracy_test:" , accuracy_test / 10)
print("f1_test:" , f1_test / 10)
# Out:
# Training Decision Tree model...
# Training bagging classifier...
# Done!
# Time: 4.268731844997092
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3576.0       4347.0
#            true_positive       3657.0       4420.0
# None
#
# Precision:  0.5041633397969659
# Recall:  0.5472328834963477
# Accuracy:  0.49975
# f1_score:  0.5248159582047021
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        819.0       1258.0
#            true_positive       1010.0        913.0
# None
#
# Precision:  0.4205435283279595
# Recall:  0.4747789911596464
# Accuracy:  0.433
# f1_score:  0.44601856375183196
# Training bagging classifier...
# Done!
# Time: 6.12311253399821
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3579.0       4344.0
#            true_positive       3708.0       4369.0
# None
#
# Precision:  0.5014346378973947
# Recall:  0.5409186579175437
# Accuracy:  0.49675
# f1_score:  0.5204288266825492
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        812.0       1265.0
#            true_positive       1000.0        923.0
# None
#
# Precision:  0.4218464351005484
# Recall:  0.4799791991679667
# Accuracy:  0.43375
# f1_score:  0.44903916322062754
# Training bagging classifier...
# Done!
# Time: 4.385564339005214
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3587.0       4336.0
#            true_positive       3693.0       4384.0
# None
#
# Precision:  0.5027522935779817
# Recall:  0.5427757830877801
# Accuracy:  0.4981875
# f1_score:  0.5219979758290171
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        814.0       1263.0
#            true_positive       1014.0        909.0
# None
#
# Precision:  0.4185082872928177
# Recall:  0.47269890795631825
# Accuracy:  0.43075
# f1_score:  0.44395604395604393
# Training bagging classifier...
# Done!
# Time: 5.328657480997208
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3600.0       4323.0
#            true_positive       3676.0       4401.0
# None
#
# Precision:  0.5044704264099037
# Recall:  0.5448805249473815
# Accuracy:  0.5000625
# f1_score:  0.5238973870602941
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        819.0       1258.0
#            true_positive       1001.0        922.0
# None
#
# Precision:  0.42293577981651376
# Recall:  0.4794591783671347
# Accuracy:  0.43525
# f1_score:  0.4494272483548623
# Training bagging classifier...
# Done!
# Time: 1.3378849229993648
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3574.0       4349.0
#            true_positive       3652.0       4425.0
# None
#
# Precision:  0.5043309778892181
# Recall:  0.5478519252197598
# Accuracy:  0.4999375
# f1_score:  0.5251913833006943
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        812.0       1265.0
#            true_positive       1007.0        916.0
# None
#
# Precision:  0.4199908298945438
# Recall:  0.4763390535621425
# Accuracy:  0.432
# f1_score:  0.44639376218323584
# Training bagging classifier...
# Done!
# Time: 5.879974960000254
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3576.0       4347.0
#            true_positive       3653.0       4424.0
# None
#
# Precision:  0.5043894652833201
# Recall:  0.5477281168750774
# Accuracy:  0.5
# f1_score:  0.5251661918328585
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        818.0       1259.0
#            true_positive       1024.0        899.0
# None
#
# Precision:  0.4165894346617238
# Recall:  0.4674986999479979
# Accuracy:  0.42925
# f1_score:  0.44057828963489337
# Training bagging classifier...
# Done!
# Time: 1.30999996799801
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3587.0       4336.0
#            true_positive       3679.0       4398.0
# None
#
# Precision:  0.5035493473780628
# Recall:  0.5445090999133342
# Accuracy:  0.4990625
# f1_score:  0.5232288382606627
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        816.0       1261.0
#            true_positive       1017.0        906.0
# None
#
# Precision:  0.41808952468850946
# Recall:  0.4711388455538221
# Accuracy:  0.4305
# f1_score:  0.4430317848410758
# Training bagging classifier...
# Done!
# Time: 5.911915657998179
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3579.0       4344.0
#            true_positive       3680.0       4397.0
# None
#
# Precision:  0.5030316897380163
# Recall:  0.5443852915686517
# Accuracy:  0.4985
# f1_score:  0.5228921393744796
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        810.0       1267.0
#            true_positive       1007.0        916.0
# None
#
# Precision:  0.4196060467246908
# Recall:  0.4763390535621425
# Accuracy:  0.4315
# f1_score:  0.44617632732586465
# Training bagging classifier...
# Done!
# Time: 1.3134803970024223
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3579.0       4344.0
#            true_positive       3675.0       4402.0
# None
#
# Precision:  0.5033158015092614
# Recall:  0.5450043332920639
# Accuracy:  0.4988125
# f1_score:  0.5233311537775664
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        805.0       1272.0
#            true_positive       1011.0        912.0
# None
#
# Precision:  0.4175824175824176
# Recall:  0.47425897035881437
# Accuracy:  0.42925
# f1_score:  0.4441197954711468
# Training bagging classifier...
# Done!
# Time: 8.926636500000313
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3577.0       4346.0
#            true_positive       3630.0       4447.0
# None
#
# Precision:  0.5057432048220175
# Recall:  0.5505757088027733
# Accuracy:  0.5015
# f1_score:  0.5272080616478957
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        812.0       1265.0
#            true_positive       1011.0        912.0
# None
#
# Precision:  0.41892512632062473
# Recall:  0.47425897035881437
# Accuracy:  0.431
# f1_score:  0.4448780487804878
# The final results:
# Time: 4.4785958604996265
# precision_train: 0.5037181184302143
# recall_train: 0.5455862325120713
# accuracy_train: 0.49925625
# f1_train: 0.523815791597072
# precision_test: 0.41946174104103495
# recall_test: 0.47467498699948
# accuracy_test: 0.43162500000000004
# f1_test: 0.44536190275200693

# %%
print('Training MLP model directly ...')

Time = 0.0
precision_train = 0.0
recall_train = 0.0
accuracy_train = 0.0
f1_train = 0.0

precision_test = 0.0
recall_test = 0.0
accuracy_test = 0.0
f1_test = 0.0

for i in range(10):

    print('Training bagging classifier...')
    pu_start = time.perf_counter()
    model = BaggingClassifierPU(model3,
                             n_estimators = 50, 
                             n_jobs = -1, 
                             max_samples = sum(y) 
                        )
    model.fit(X, y)
    pre = model.predict(X)
    pu_end = time.perf_counter()
    print('Done!')
    print('Time:', pu_end - pu_start)
    Time += (pu_end - pu_start)
    
    #train data
    print('---- {} ----'.format('PU Bagging Train data'))
    print(print_cm(sklearn.metrics.confusion_matrix(y_orig, pre), labels=['negative', 'positive']))
    print('')
    print('Precision: ', precision_score(y_orig, pre))
    print('Recall: ', recall_score(y_orig, pre))
    print('Accuracy: ', accuracy_score(y_orig, pre))
    print('f1_score: ', f1_score(y_orig, pre))
   
    #test data
    pre_test = model.predict(x_test)
    print('---- {} ----'.format('PU Bagging Test data'))
    print(print_cm(sklearn.metrics.confusion_matrix(y_test,pre_test ), labels=['negative', 'positive']))
    print('')
    print('Precision: ', precision_score(y_test, pre_test))
    print('Recall: ', recall_score(y_test, pre_test))
    print('Accuracy: ', accuracy_score(y_test, pre_test))
    print('f1_score: ', f1_score(y_test, pre_test))
    
    
    precision_train += precision_score(y_orig, pre)
    recall_train += recall_score(y_orig, pre)
    accuracy_train += accuracy_score(y_orig, pre)
    f1_train += f1_score(y_orig, pre)
    
    precision_test += precision_score(y_test,pre_test)
    recall_test += recall_score(y_test, pre_test)
    accuracy_test += accuracy_score(y_test, pre_test)
    f1_test += f1_score(y_test, pre_test)
    

print("The final results:")
print("Time:" , Time / 10)
print("precision_train:" , precision_train / 10)
print("recall_train:" , recall_train / 10)
print("accuracy_train:" , accuracy_train / 10)
print("f1_train:" , f1_train / 10)
print("precision_test:" , precision_test / 10)
print("recall_test:" , recall_test / 10)
print("accuracy_test:" , accuracy_test / 10)
print("f1_test:" , f1_test / 10)
# Out:
# Training MLP model directly ...
# Training bagging classifier...
# Done!
# Time: 11.541991398997197
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       6013.0       1910.0
#            true_positive       6093.0       1984.0
# None
#
# Precision:  0.5095017976373909
# Recall:  0.2456357558499443
# Accuracy:  0.4998125
# f1_score:  0.3314677136412998
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1551.0        526.0
#            true_positive       1473.0        450.0
# None
#
# Precision:  0.4610655737704918
# Recall:  0.23400936037441497
# Accuracy:  0.50025
# f1_score:  0.3104518799586064
# Training bagging classifier...
# Done!
# Time: 11.90349163999781
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       5182.0       2741.0
#            true_positive       5257.0       2820.0
# None
#
# Precision:  0.5071030390217587
# Recall:  0.3491395320044571
# Accuracy:  0.500125
# f1_score:  0.41355037395512534
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1332.0        745.0
#            true_positive       1254.0        669.0
# None
#
# Precision:  0.47312588401697314
# Recall:  0.34789391575663026
# Accuracy:  0.50025
# f1_score:  0.40095894516032365
# Training bagging classifier...
# Done!
# Time: 11.429854095003975
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       2557.0       5366.0
#            true_positive       2550.0       5527.0
# None
#
# Precision:  0.5073900670155146
# Recall:  0.6842887210597994
# Accuracy:  0.50525
# f1_score:  0.5827095413811282
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        632.0       1445.0
#            true_positive        641.0       1282.0
# None
#
# Precision:  0.47011367803447013
# Recall:  0.6666666666666666
# Accuracy:  0.4785
# f1_score:  0.5513978494623655
# Training bagging classifier...
# Done!
# Time: 11.568473872997856
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       7923.0          0.0
#            true_positive       8077.0          0.0
# None
#
# Precision:  0.0
# Recall:  0.0
# Accuracy:  0.4951875
# f1_score:  0.0
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       2077.0          0.0
#            true_positive       1923.0          0.0
# None
#
# Precision:  0.0
# Recall:  0.0
# Accuracy:  0.51925
# f1_score:  0.0
# Training bagging classifier...
# Done!
# Time: 11.44451730500441
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       4893.0       3030.0
#            true_positive       5052.0       3025.0
# None
#
# Precision:  0.4995871180842279
# Recall:  0.3745202426643556
# Accuracy:  0.494875
# f1_score:  0.42810642513444663
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1329.0        748.0
#            true_positive       1170.0        753.0
# None
#
# Precision:  0.5016655562958028
# Recall:  0.3915756630265211
# Accuracy:  0.5205
# f1_score:  0.43983644859813087
# Training bagging classifier...
# Done!
# Time: 11.366969750000862
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       7342.0        581.0
#            true_positive       7475.0        602.0
# None
#
# Precision:  0.5088757396449705
# Recall:  0.07453262349882382
# Accuracy:  0.4965
# f1_score:  0.13002159827213822
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1916.0        161.0
#            true_positive       1783.0        140.0
# None
#
# Precision:  0.46511627906976744
# Recall:  0.07280291211648465
# Accuracy:  0.514
# f1_score:  0.12589928057553956
# Training bagging classifier...
# Done!
# Time: 12.10638418799499
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       5553.0       2370.0
#            true_positive       5652.0       2425.0
# None
#
# Precision:  0.5057351407716372
# Recall:  0.30023523585489664
# Accuracy:  0.498625
# f1_score:  0.37678682411435677
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1443.0        634.0
#            true_positive       1347.0        576.0
# None
#
# Precision:  0.47603305785123967
# Recall:  0.2995319812792512
# Accuracy:  0.50475
# f1_score:  0.3676986913501436
# Training bagging classifier...
# Done!
# Time: 11.925016193999909
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative        887.0       7036.0
#            true_positive        916.0       7161.0
# None
#
# Precision:  0.504402338522223
# Recall:  0.8865915562708927
# Accuracy:  0.503
# f1_score:  0.6429918290383407
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        243.0       1834.0
#            true_positive        213.0       1710.0
# None
#
# Precision:  0.48250564334085777
# Recall:  0.8892355694227769
# Accuracy:  0.48825
# f1_score:  0.6255716114871044
# Training bagging classifier...
# Done!
# Time: 11.10304382200411
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative         16.0       7907.0
#            true_positive         15.0       8062.0
# None
#
# Precision:  0.5048531529839063
# Recall:  0.9981428748297635
# Accuracy:  0.504875
# f1_score:  0.6705481161107876
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative          3.0       2074.0
#            true_positive          4.0       1919.0
# None
#
# Precision:  0.4805910343100426
# Recall:  0.9979199167966719
# Accuracy:  0.4805
# f1_score:  0.6487491548343476
# Training bagging classifier...
# Done!
# Time: 10.148130882997066
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       4292.0       3631.0
#            true_positive       4324.0       3753.0
# None
#
# Precision:  0.508261105092091
# Recall:  0.4646527175931658
# Accuracy:  0.5028125
# f1_score:  0.4854795938167001
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1070.0       1007.0
#            true_positive       1039.0        884.0
# None
#
# Precision:  0.46747752511898466
# Recall:  0.4596983879355174
# Accuracy:  0.4885
# f1_score:  0.4635553224960671
# The final results:
# Time: 11.453787314899818
# precision_train: 0.45557094987737196
# recall_train: 0.43777392596260983
# accuracy_train: 0.5001062500000001
# f1_train: 0.4061662015464324
# precision_test: 0.427769423180863
# recall_test: 0.4359334373374935
# accuracy_test: 0.49947500000000006
# f1_test: 0.39341191839226286

# %%
print('Training SVM model...')
Time = 0.0
precision_train = 0.0
recall_train = 0.0
accuracy_train = 0.0
f1_train = 0.0

precision_test = 0.0
recall_test = 0.0
accuracy_test = 0.0
f1_test = 0.0

for i in range(10):

    print('Training bagging classifier...')
    pu_start = time.perf_counter()
    model = BaggingClassifierPU(model4,
                             n_estimators = 50, 
                             n_jobs = -1, 
                             max_samples = sum(y) 
                        )
    model.fit(X, y)
    pre = model.predict(X)
    pu_end = time.perf_counter()
    print('Done!')
    print('Time:', pu_end - pu_start)
    Time += (pu_end - pu_start)
    
    #train data
    print('---- {} ----'.format('PU Bagging Train data'))
    print(print_cm(sklearn.metrics.confusion_matrix(y_orig, pre), labels=['negative', 'positive']))
    print('')
    print('Precision: ', precision_score(y_orig, pre))
    print('Recall: ', recall_score(y_orig, pre))
    print('Accuracy: ', accuracy_score(y_orig, pre))
    print('f1_score: ', f1_score(y_orig, pre))
   
    #test data
    pre_test = model.predict(x_test)
    print('---- {} ----'.format('PU Bagging Test data'))
    print(print_cm(sklearn.metrics.confusion_matrix(y_test,pre_test ), labels=['negative', 'positive']))
    print('')
    print('Precision: ', precision_score(y_test, pre_test))
    print('Recall: ', recall_score(y_test, pre_test))
    print('Accuracy: ', accuracy_score(y_test, pre_test))
    print('f1_score: ', f1_score(y_test, pre_test))
    
    
    precision_train += precision_score(y_orig, pre)
    recall_train += recall_score(y_orig, pre)
    accuracy_train += accuracy_score(y_orig, pre)
    f1_train += f1_score(y_orig, pre)
    
    precision_test += precision_score(y_test,pre_test)
    recall_test += recall_score(y_test, pre_test)
    accuracy_test += accuracy_score(y_test, pre_test)
    f1_test += f1_score(y_test, pre_test)
    

print("The final results:")
print("Time:" , Time / 10)
print("precision_train:" , precision_train / 10)
print("recall_train:" , recall_train / 10)
print("accuracy_train:" , accuracy_train / 10)
print("f1_train:" , f1_train / 10)
print("precision_test:" , precision_test / 10)
print("recall_test:" , recall_test / 10)
print("accuracy_test:" , accuracy_test / 10)
print("f1_test:" , f1_test / 10)
# Out:
# Training SVM model...
# Training bagging classifier...
# Done!
# Time: 4.4835277419988415
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative        144.0       7779.0
#            true_positive        154.0       7923.0
# None
#
# Precision:  0.5045854031333588
# Recall:  0.9809335149189056
# Accuracy:  0.5041875
# f1_score:  0.6663863072458892
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative         37.0       2040.0
#            true_positive         27.0       1896.0
# None
#
# Precision:  0.4817073170731707
# Recall:  0.9859594383775351
# Accuracy:  0.48325
# f1_score:  0.6472094214029697
# Training bagging classifier...
# Done!
# Time: 6.110986684005184
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       7303.0        620.0
#            true_positive       7438.0        639.0
# None
#
# Precision:  0.5075456711675933
# Recall:  0.07911353225207379
# Accuracy:  0.496375
# f1_score:  0.13688946015424164
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1907.0        170.0
#            true_positive       1770.0        153.0
# None
#
# Precision:  0.47368421052631576
# Recall:  0.07956318252730109
# Accuracy:  0.515
# f1_score:  0.13624220837043632
# Training bagging classifier...
# Done!
# Time: 5.3923255410045385
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative        579.0       7344.0
#            true_positive        597.0       7480.0
# None
#
# Precision:  0.5045871559633027
# Recall:  0.9260864182245884
# Accuracy:  0.5036875
# f1_score:  0.6532465831186411
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        160.0       1917.0
#            true_positive        143.0       1780.0
# None
#
# Precision:  0.4814714633486611
# Recall:  0.9256370254810192
# Accuracy:  0.485
# f1_score:  0.6334519572953736
# Training bagging classifier...
# Done!
# Time: 6.496858547994634
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative          0.0       7923.0
#            true_positive          0.0       8077.0
# None
#
# Precision:  0.5048125
# Recall:  1.0
# Accuracy:  0.5048125
# f1_score:  0.6709307637994767
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative          0.0       2077.0
#            true_positive          0.0       1923.0
# None
#
# Precision:  0.48075
# Recall:  1.0
# Accuracy:  0.48075
# f1_score:  0.6493331082221847
# Training bagging classifier...
# Done!
# Time: 5.351290523001808
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       7888.0         35.0
#            true_positive       8046.0         31.0
# None
#
# Precision:  0.4696969696969697
# Recall:  0.0038380586851553796
# Accuracy:  0.4949375
# f1_score:  0.007613901510499816
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       2072.0          5.0
#            true_positive       1916.0          7.0
# None
#
# Precision:  0.5833333333333334
# Recall:  0.003640145605824233
# Accuracy:  0.51975
# f1_score:  0.007235142118863048
# Training bagging classifier...
# Done!
# Time: 6.62729309599672
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       7773.0        150.0
#            true_positive       7927.0        150.0
# None
#
# Precision:  0.5
# Recall:  0.01857125170236474
# Accuracy:  0.4951875
# f1_score:  0.035812343320997975
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       2044.0         33.0
#            true_positive       1890.0         33.0
# None
#
# Precision:  0.5
# Recall:  0.0171606864274571
# Accuracy:  0.51925
# f1_score:  0.03318250377073907
# Training bagging classifier...
# Done!
# Time: 5.614477077004267
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative        265.0       7658.0
#            true_positive        269.0       7808.0
# None
#
# Precision:  0.5048493469546101
# Recall:  0.9666955552804259
# Accuracy:  0.5045625
# f1_score:  0.6632969460136771
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative         64.0       2013.0
#            true_positive         61.0       1862.0
# None
#
# Precision:  0.48051612903225804
# Recall:  0.968278731149246
# Accuracy:  0.4815
# f1_score:  0.6422904449810278
# Training bagging classifier...
# Done!
# Time: 6.595774887995503
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       7233.0        690.0
#            true_positive       7357.0        720.0
# None
#
# Precision:  0.5106382978723404
# Recall:  0.08914200817135075
# Accuracy:  0.4970625
# f1_score:  0.15178665542321068
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1880.0        197.0
#            true_positive       1755.0        168.0
# None
#
# Precision:  0.4602739726027397
# Recall:  0.0873634945397816
# Accuracy:  0.512
# f1_score:  0.14685314685314688
# Training bagging classifier...
# Done!
# Time: 4.83846983499825
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative        250.0       7673.0
#            true_positive        246.0       7831.0
# None
#
# Precision:  0.5050954592363261
# Recall:  0.9695431472081218
# Accuracy:  0.5050625
# f1_score:  0.664178788007294
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative         54.0       2023.0
#            true_positive         58.0       1865.0
# None
#
# Precision:  0.47968106995884774
# Recall:  0.9698387935517421
# Accuracy:  0.47975
# f1_score:  0.6418860781276888
# Training bagging classifier...
# Done!
# Time: 6.460046008003701
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative        529.0       7394.0
#            true_positive        539.0       7538.0
# None
#
# Precision:  0.504821859094562
# Recall:  0.9332673022161694
# Accuracy:  0.5041875
# f1_score:  0.6552218697031597
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        142.0       1935.0
#            true_positive        132.0       1791.0
# None
#
# Precision:  0.4806763285024155
# Recall:  0.9313572542901716
# Accuracy:  0.48325
# f1_score:  0.6340945300053107
# The final results:
# Time: 5.797104994200344
# precision_train: 0.5016632663119063
# recall_train: 0.5967190788659156
# accuracy_train: 0.50100625
# f1_train: 0.4305363618297087
# precision_test: 0.4902093824377742
# recall_test: 0.5968798751950077
# accuracy_test: 0.49595
# f1_test: 0.41717785411477404

# %%
print('Training Naive Bayesianayes model...')
Time = 0.0
precision_train = 0.0
recall_train = 0.0
accuracy_train = 0.0
f1_train = 0.0

precision_test = 0.0
recall_test = 0.0
accuracy_test = 0.0
f1_test = 0.0

for i in range(10):

    print('Training bagging classifier...')
    pu_start = time.perf_counter()
    model = BaggingClassifierPU(model5,
                             n_estimators = 50, 
                             n_jobs = -1, 
                             max_samples = sum(y) 
                        )
    model.fit(X, y)
    pre = model.predict(X)
    pu_end = time.perf_counter()
    print('Done!')
    print('Time:', pu_end - pu_start)
    Time += (pu_end - pu_start)
    
    #train data
    print('---- {} ----'.format('PU Bagging Train data'))
    print(print_cm(sklearn.metrics.confusion_matrix(y_orig, pre), labels=['negative', 'positive']))
    print('')
    print('Precision: ', precision_score(y_orig, pre))
    print('Recall: ', recall_score(y_orig, pre))
    print('Accuracy: ', accuracy_score(y_orig, pre))
    print('f1_score: ', f1_score(y_orig, pre))
   
    #test data
    pre_test = model.predict(x_test)
    print('---- {} ----'.format('PU Bagging Test data'))
    print(print_cm(sklearn.metrics.confusion_matrix(y_test,pre_test ), labels=['negative', 'positive']))
    print('')
    print('Precision: ', precision_score(y_test, pre_test))
    print('Recall: ', recall_score(y_test, pre_test))
    print('Accuracy: ', accuracy_score(y_test, pre_test))
    print('f1_score: ', f1_score(y_test, pre_test))
    
    
    precision_train += precision_score(y_orig, pre)
    recall_train += recall_score(y_orig, pre)
    accuracy_train += accuracy_score(y_orig, pre)
    f1_train += f1_score(y_orig, pre)
    
    precision_test += precision_score(y_test,pre_test)
    recall_test += recall_score(y_test, pre_test)
    accuracy_test += accuracy_score(y_test, pre_test)
    f1_test += f1_score(y_test, pre_test)
    

print("The final results:")
print("Time:" , Time / 10)
print("precision_train:" , precision_train / 10)
print("recall_train:" , recall_train / 10)
print("accuracy_train:" , accuracy_train / 10)
print("f1_train:" , f1_train / 10)
print("precision_test:" , precision_test / 10)
print("recall_test:" , recall_test / 10)
print("accuracy_test:" , accuracy_test / 10)
print("f1_test:" , f1_test / 10)
# Out:
# Training Naive Bayesianayes model...
# Training bagging classifier...
# Done!
# Time: 1.0366294069972355
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3877.0       4046.0
#            true_positive       4018.0       4059.0
# None
#
# Precision:  0.5008019740900679
# Recall:  0.5025380710659898
# Accuracy:  0.496
# f1_score:  0.5016685205784204
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1062.0       1015.0
#            true_positive        922.0       1001.0
# None
#
# Precision:  0.4965277777777778
# Recall:  0.5205408216328653
# Accuracy:  0.51575
# f1_score:  0.5082508250825083
# Training bagging classifier...
# Done!
# Time: 4.2291827790031675
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3868.0       4055.0
#            true_positive       4009.0       4068.0
# None
#
# Precision:  0.5008001969715622
# Recall:  0.5036523461681317
# Accuracy:  0.496
# f1_score:  0.5022222222222222
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1061.0       1016.0
#            true_positive        920.0       1003.0
# None
#
# Precision:  0.4967805844477464
# Recall:  0.5215808632345293
# Accuracy:  0.516
# f1_score:  0.5088787417554541
# Training bagging classifier...
# Done!
# Time: 5.547205798997311
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3871.0       4052.0
#            true_positive       4014.0       4063.0
# None
#
# Precision:  0.5006777572396796
# Recall:  0.5030333044447196
# Accuracy:  0.495875
# f1_score:  0.501852766798419
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1062.0       1015.0
#            true_positive        920.0       1003.0
# None
#
# Precision:  0.49702675916749256
# Recall:  0.5215808632345293
# Accuracy:  0.51625
# f1_score:  0.5090078660238518
# Training bagging classifier...
# Done!
# Time: 0.9982881589967292
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3887.0       4036.0
#            true_positive       4029.0       4048.0
# None
#
# Precision:  0.5007422068283028
# Recall:  0.5011761792744831
# Accuracy:  0.4959375
# f1_score:  0.5009590990656518
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1067.0       1010.0
#            true_positive        925.0        998.0
# None
#
# Precision:  0.49701195219123506
# Recall:  0.5189807592303692
# Accuracy:  0.51625
# f1_score:  0.5077588399898245
# Training bagging classifier...
# Done!
# Time: 3.9545906119965366
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3888.0       4035.0
#            true_positive       4031.0       4046.0
# None
#
# Precision:  0.5006806088355401
# Recall:  0.5009285625851182
# Accuracy:  0.495875
# f1_score:  0.5008045550191855
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1068.0       1009.0
#            true_positive        925.0        998.0
# None
#
# Precision:  0.49725959142999504
# Recall:  0.5189807592303692
# Accuracy:  0.5165
# f1_score:  0.5078880407124682
# Training bagging classifier...
# Done!
# Time: 4.888065405000816
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3881.0       4042.0
#            true_positive       4024.0       4053.0
# None
#
# Precision:  0.5006794317479926
# Recall:  0.5017952209978953
# Accuracy:  0.495875
# f1_score:  0.5012367054167697
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1066.0       1011.0
#            true_positive        923.0       1000.0
# None
#
# Precision:  0.4972650422675286
# Recall:  0.5200208008320333
# Accuracy:  0.5165
# f1_score:  0.5083884087442806
# Training bagging classifier...
# Done!
# Time: 1.2330049309966853
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3880.0       4043.0
#            true_positive       4023.0       4054.0
# None
#
# Precision:  0.5006792639249105
# Recall:  0.5019190293425777
# Accuracy:  0.495875
# f1_score:  0.501298380116236
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1066.0       1011.0
#            true_positive        923.0       1000.0
# None
#
# Precision:  0.4972650422675286
# Recall:  0.5200208008320333
# Accuracy:  0.5165
# f1_score:  0.5083884087442806
# Training bagging classifier...
# Done!
# Time: 3.569395799000631
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3883.0       4040.0
#            true_positive       4027.0       4050.0
# None
#
# Precision:  0.5006180469715699
# Recall:  0.501423795963848
# Accuracy:  0.4958125
# f1_score:  0.5010205975134534
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1067.0       1010.0
#            true_positive        924.0        999.0
# None
#
# Precision:  0.49726231956197114
# Recall:  0.5195007800312013
# Accuracy:  0.5165
# f1_score:  0.5081383519837233
# Training bagging classifier...
# Done!
# Time: 3.5391862969991053
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3872.0       4051.0
#            true_positive       4014.0       4063.0
# None
#
# Precision:  0.5007394626571359
# Recall:  0.5030333044447196
# Accuracy:  0.4959375
# f1_score:  0.5018837625841518
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1062.0       1015.0
#            true_positive        920.0       1003.0
# None
#
# Precision:  0.49702675916749256
# Recall:  0.5215808632345293
# Accuracy:  0.51625
# f1_score:  0.5090078660238518
# Training bagging classifier...
# Done!
# Time: 1.952710150006169
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3846.0       4077.0
#            true_positive       3987.0       4090.0
# None
#
# Precision:  0.5007958858822089
# Recall:  0.5063761297511452
# Accuracy:  0.496
# f1_score:  0.5035705491258311
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative       1058.0       1019.0
#            true_positive        918.0       1005.0
# None
#
# Precision:  0.4965415019762846
# Recall:  0.5226209048361935
# Accuracy:  0.51575
# f1_score:  0.5092475297694452
# The final results:
# Time: 3.094825933799439
# precision_train: 0.500721483514897
# recall_train: 0.5025875944038628
# accuracy_train: 0.49591874999999985
# f1_train: 0.501651715844034
# precision_test: 0.49699673302550523
# recall_test: 0.5205408216328653
# accuracy_test: 0.5162249999999999
# f1_test: 0.5084954878829688

# %%
print('Training Random Forest model...')
Time = 0.0
precision_train = 0.0
recall_train = 0.0
accuracy_train = 0.0
f1_train = 0.0

precision_test = 0.0
recall_test = 0.0
accuracy_test = 0.0
f1_test = 0.0

for i in range(10):

    print('Training bagging classifier...')
    pu_start = time.perf_counter()
    model = BaggingClassifierPU(model6,
                             n_estimators = 50, 
                             n_jobs = -1, 
                             max_samples = sum(y) 
                        )
    model.fit(X, y)
    pre = model.predict(X)
    pu_end = time.perf_counter()
    print('Done!')
    print('Time:', pu_end - pu_start)
    Time += (pu_end - pu_start)
    
    #train data
    print('---- {} ----'.format('PU Bagging Train data'))
    print(print_cm(sklearn.metrics.confusion_matrix(y_orig, pre), labels=['negative', 'positive']))
    print('')
    print('Precision: ', precision_score(y_orig, pre))
    print('Recall: ', recall_score(y_orig, pre))
    print('Accuracy: ', accuracy_score(y_orig, pre))
    print('f1_score: ', f1_score(y_orig, pre))
   
    #test data
    pre_test = model.predict(x_test)
    print('---- {} ----'.format('PU Bagging Test data'))
    print(print_cm(sklearn.metrics.confusion_matrix(y_test,pre_test ), labels=['negative', 'positive']))
    print('')
    print('Precision: ', precision_score(y_test, pre_test))
    print('Recall: ', recall_score(y_test, pre_test))
    print('Accuracy: ', accuracy_score(y_test, pre_test))
    print('f1_score: ', f1_score(y_test, pre_test))
    
    
    precision_train += precision_score(y_orig, pre)
    recall_train += recall_score(y_orig, pre)
    accuracy_train += accuracy_score(y_orig, pre)
    f1_train += f1_score(y_orig, pre)
    
    precision_test += precision_score(y_test,pre_test)
    recall_test += recall_score(y_test, pre_test)
    accuracy_test += accuracy_score(y_test, pre_test)
    f1_test += f1_score(y_test, pre_test)
    

print("The final results:")
print("Time:" , Time / 10)
print("precision_train:" , precision_train / 10)
print("recall_train:" , recall_train / 10)
print("accuracy_train:" , accuracy_train / 10)
print("f1_train:" , f1_train / 10)
print("precision_test:" , precision_test / 10)
print("recall_test:" , recall_test / 10)
print("accuracy_test:" , accuracy_test / 10)
print("f1_test:" , f1_test / 10)
# Out:
# Training Random Forest model...
# Training bagging classifier...
# Done!
# Time: 66.97128426400013
# ---- PU Bagging Train data ----
#                         pred_negative        pred_positive
#            true_negative       3318.0       4605.0
#            true_positive       3198.0       4879.0
# None
#
# Precision:  0.5144453816954871
# Recall:  0.6040609137055838
# Accuracy:  0.5123125
# f1_score:  0.5556631171345595
# ---- PU Bagging Test data ----
#                         pred_negative        pred_positive
#            true_negative        711.0       1366.0
#            true_positive        909.0       1014.0
# None
#
# Precision:  0.4260504201680672
# Recall:  0.5273010920436817
# Accuracy:  0.43125
# f1_score:  0.47129909365558914
# Training bagging classifier...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-1f45c13334df> in <module>
#      20                              max_samples = sum(y)
#      21                         )
# ---> 22     model.fit(X, y)
#      23     pre = model.predict(X)
#      24     pu_end = time.perf_counter()
#
# ~/code/ReachabilityofUPN/baggingPU.py in fit(self, X, y, sample_weight)
#     193
#     194     def fit(self, X, y, sample_weight=None):
# --> 195         return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#     196
#     197     def _fit(self, X, y, max_samples=None, max_depth=None, sample_weight=None):
#
# ~/code/ReachabilityofUPN/baggingPU.py in _fit(self, X, y, max_samples, max_depth, sample_weight)
#     290
#     291         if self.oob_score:
# --> 292             self._set_oob_score(X, y)
#     293
#     294         return self
#
# ~/code/ReachabilityofUPN/baggingPU.py in _set_oob_score(self, X, y)
#     381             if hasattr(estimator, "predict_proba"):
#     382                 predictions[mask, :] += estimator.predict_proba(
# --> 383                     (X[mask, :])[:, features])
#     384
#     385             else:
#
# ~/anaconda3/envs/qhd_env/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in predict_proba(self, X)
#     684             delayed(_accumulate_prediction)(e.predict_proba, X, all_proba,
#     685                                             lock)
# --> 686             for e in self.estimators_)
#     687
#     688         for proba in all_proba:
#
# ~/anaconda3/envs/qhd_env/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1059
#    1060             with self._backend.retrieval_context():
# -> 1061                 self.retrieve()
#    1062             # Make sure that we get a last message telling us we are done
#    1063             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/envs/qhd_env/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     938             try:
#     939                 if getattr(self._backend, 'supports_timeout', False):
# --> 940                     self._output.extend(job.get(timeout=self.timeout))
#     941                 else:
#     942                     self._output.extend(job.get())
#
# ~/anaconda3/envs/qhd_env/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/anaconda3/envs/qhd_env/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/anaconda3/envs/qhd_env/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/envs/qhd_env/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
print('Training XGboost model directly ...')
Time = 0.0
precision_train = 0.0
recall_train = 0.0
accuracy_train = 0.0
f1_train = 0.0

precision_test = 0.0
recall_test = 0.0
accuracy_test = 0.0
f1_test = 0.0

for i in range(10):

    print('Training bagging classifier...')
    pu_start = time.perf_counter()
    model = BaggingClassifierPU(model7,
                             n_estimators = 50, 
                             n_jobs = -1, 
                             max_samples = sum(y) 
                        )
    model.fit(X, y)
    pre = model.predict(X)
    pu_end = time.perf_counter()
    print('Done!')
    print('Time:', pu_end - pu_start)
    Time += (pu_end - pu_start)
    
    #train data
    print('---- {} ----'.format('PU Bagging Train data'))
    print(print_cm(sklearn.metrics.confusion_matrix(y_orig, pre), labels=['negative', 'positive']))
    print('')
    print('Precision: ', precision_score(y_orig, pre))
    print('Recall: ', recall_score(y_orig, pre))
    print('Accuracy: ', accuracy_score(y_orig, pre))
    print('f1_score: ', f1_score(y_orig, pre))
   
    #test data
    pre_test = model.predict(x_test)
    print('---- {} ----'.format('PU Bagging Test data'))
    print(print_cm(sklearn.metrics.confusion_matrix(y_test,pre_test ), labels=['negative', 'positive']))
    print('')
    print('Precision: ', precision_score(y_test, pre_test))
    print('Recall: ', recall_score(y_test, pre_test))
    print('Accuracy: ', accuracy_score(y_test, pre_test))
    print('f1_score: ', f1_score(y_test, pre_test))
    
    
    precision_train += precision_score(y_orig, pre)
    recall_train += recall_score(y_orig, pre)
    accuracy_train += accuracy_score(y_orig, pre)
    f1_train += f1_score(y_orig, pre)
    
    precision_test += precision_score(y_test,pre_test)
    recall_test += recall_score(y_test, pre_test)
    accuracy_test += accuracy_score(y_test, pre_test)
    f1_test += f1_score(y_test, pre_test)
    
print("===========================")
print("The final results:")
print("Time:" , Time / 10)
print("precision_train:" , precision_train / 10)
print("recall_train:" , recall_train / 10)
print("accuracy_train:" , accuracy_train / 10)
print("f1_train:" , f1_train / 10)
print("precision_test:" , precision_test / 10)
print("recall_test:" , recall_test / 10)
print("accuracy_test:" , accuracy_test / 10)
print("f1_test:" , f1_test / 10)
# Out:
# Training XGboost model directly ...
# Training bagging classifier...
